# %%
# importing libs
import numpy as np
import tensorflow as tf
from keras import backend as K
from keras.layers import Input, Lambda,Dense, GaussianNoise
from keras.models import Model
from keras import regularizers
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam,SGD
import random as rn

# %%
# defining parameters
M = 256
R = 1/4
k = int(np.log2(M))
n_channel = int(k/R)

print ('M:',M,'k:',k,'n_coded:',n_channel,'R:',R)
# Out:
# M: 256 k: 8 n_coded: 32 R: 0.25

# %%
#generating data of size N
N = 1000000
label = np.random.randint(M,size=N)

# %%
# creating one hot encoded vectors
data = []
for i in label:
    temp = np.zeros(M)
    temp[i] = 1
    data.append(temp)

# %%
data = np.array(data)
print (data.shape)
# Out:
# (1000000, 256)

# %%
temp_check = [0,23,45,67,88,96,72,250,350]
for i in temp_check:
    print(label[i],data[i])

# %%
#Hyperparameters
lr=0.001
Eb_N0db=5
Eb_N0=10.0**(Eb_N0db/10.0)

# %%
# defining autoencoder and it's layer
input_signal = Input(shape=(M,))
encoded = Dense(M, activation='relu')(input_signal)
encoded1 = Dense(M, activation='relu')(encoded)
encoded2 = Dense(2*n_channel, activation='linear')(encoded1)
encoded3 = Lambda(lambda x: np.sqrt(n_channel)*K.l2_normalize(x,axis=1))(encoded2)

encoded4 = GaussianNoise(np.sqrt(1/(2*R*Eb_N0)))(encoded3)

decoded = Dense(M, activation='relu')(encoded4)
decoded1 = Dense(M, activation='relu')(decoded)
decoded2 = Dense(M, activation='softmax')(decoded1)

autoencoder = Model(input_signal, decoded2)
adam = Adam(lr)
autoencoder.compile(optimizer=adam, loss='categorical_crossentropy')

# %%
print (autoencoder.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256)]             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# lambda (Lambda)              (None, 64)                0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               16640
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# =================================================================
# Total params: 296,256
# Trainable params: 296,256
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
autoencoder.fit(data, data,
                epochs=50,
                batch_size=2000)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 28s 54ms/step - loss: 1.0158
# Epoch 2/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0097
# Epoch 3/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0079
# Epoch 4/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0071
# Epoch 5/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0066
# Epoch 6/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0066
# Epoch 7/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0062
# Epoch 8/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0060
# Epoch 9/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0061
# Epoch 10/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0054
# Epoch 11/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0060
# Epoch 12/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0058
# Epoch 13/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0060
# Epoch 14/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0057
# Epoch 15/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0054
# Epoch 16/50
# 500/500 [==============================] - 27s 53ms/step - loss: 0.0049
# Epoch 17/50
# 500/500 [==============================] - 27s 53ms/step - loss: 0.0054
# Epoch 18/50
# 500/500 [==============================] - 27s 53ms/step - loss: 0.0052
# Epoch 19/50
# 500/500 [==============================] - 27s 53ms/step - loss: 0.0053
# Epoch 20/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0050
# Epoch 21/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0049
# Epoch 22/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0049
# Epoch 23/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0053
# Epoch 24/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0046
# Epoch 25/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0046
# Epoch 26/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0048
# Epoch 27/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0046
# Epoch 28/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0049
# Epoch 29/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0047
# Epoch 30/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0045
# Epoch 31/50
# 500/500 [==============================] - 27s 53ms/step - loss: 0.0048
# Epoch 32/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0049
# Epoch 33/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0046
# Epoch 34/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0044
# Epoch 35/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0049
# Epoch 36/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0043
# Epoch 37/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0043
# Epoch 38/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0043
# Epoch 39/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0042
# Epoch 40/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0042
# Epoch 41/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0046
# Epoch 42/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0044
# Epoch 43/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0042
# Epoch 44/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0043
# Epoch 45/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0042
# Epoch 46/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0040
# Epoch 47/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0041
# Epoch 48/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0043
# Epoch 49/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0043
# Epoch 50/50
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0040

# %%
from keras.models import load_model
#autoencoder.save('4_7_symbol_autoencoder_v_best.model')

# %%
#autoencoder_loaded = load_model('4_7_symbol_autoencoder_v_best.model')

# %%
encoder = Model(input_signal, encoded3)

# %%
# making decoder from full autoencoder
encoded_input = Input(shape=(2*n_channel,))

deco = autoencoder.layers[-3](encoded_input)
deco1 = autoencoder.layers[-2](deco)
deco2 = autoencoder.layers[-1](deco1)
decoder = Model(encoded_input, deco2)

# %%
N = 1000000
test_label = np.random.randint(M,size=N)
test_data = []

for i in test_label:
    temp = np.zeros(M)
    temp[i] = 1
    test_data.append(temp)
    
test_data = np.array(test_data)

# %%
temp_test = 6
print (test_data[temp_test][test_label[temp_test]],test_label[temp_test])
# Out:
# 1.0 124

# %%
def frange(x, y, jump):
  while x < y:
    yield x
    x += jump

# %% [markdown]
# # BER

# %% [markdown]
# Mean

# %%
EbNodB_range = list(frange(0,11,1))
ber = [None]*len(EbNodB_range)
for i in range(0,len(EbNodB_range)):
    EbNo=10.0**(EbNodB_range[i]/10.0)
    noise_std = np.sqrt(1/(2*R*EbNo))
    noise_mean = 0
    no_errors = 0
    noise = noise_std * np.random.randn(N,2*n_channel)
    encoded_signal = encoder.predict(test_data) 
    final_signal = encoded_signal + noise
    pred_final_signal =  decoder.predict(final_signal)
    ber[i] = (pred_final_signal.round()!=test_data).mean()
    print ('SNR:',EbNodB_range[i],'BER:',ber[i])
# Out:
# SNR: 0 BER: 0.00188469921875
# SNR: 1 BER: 0.0010853125
# SNR: 2 BER: 0.00051574609375
# SNR: 3 BER: 0.00019228515625
# SNR: 4 BER: 5.337890625e-05
# SNR: 5 BER: 9.96484375e-06
# SNR: 6 BER: 1.078125e-06
# SNR: 7 BER: 9.375e-08
# SNR: 8 BER: 7.8125e-09
# SNR: 9 BER: 0.0
# SNR: 10 BER: 0.0

# %% [markdown]
# ### Matlab Array form

# %%
for n in range(0,len(EbNodB_range)):
  print(ber[n], " ",end='')
# Out:
# 0.00188469921875  0.0010853125  0.00051574609375  0.00019228515625  5.337890625e-05  9.96484375e-06  1.078125e-06  9.375e-08  7.8125e-09  0.0  0.0
